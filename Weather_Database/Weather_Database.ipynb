# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
import requests
# Import the API key.
from config import weather_api_key
# Import the random module.
import random
# Import the NumPy module.
import numpy as np
import pandas as pd

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2667ee06b2451c7eab17278a73d357eb

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 772

# %%
cities
# Out:
# ['georgetown',
#  'mataura',
#  'bethel',
#  'albany',
#  'kiruna',
#  'rikitea',
#  'mackay',
#  'hilo',
#  'taolanaro',
#  'great falls',
#  'plouzane',
#  'shumerlya',
#  'souillac',
#  'ushuaia',
#  'phan rang',
#  'minsk',
#  'carnarvon',
#  'port hardy',
#  'grand island',
#  'ponta do sol',
#  'castro',
#  'amderma',
#  'williston',
#  'hualmay',
#  'hobart',
#  'beringovskiy',
#  'pevek',
#  'sidi ali',
#  'honningsvag',
#  'saint-philippe',
#  'chuy',
#  'mahebourg',
#  'busselton',
#  'karaul',
#  'lagoa',
#  'jamestown',
#  'ancud',
#  'fairbanks',
#  'port alfred',
#  'tabukiniberu',
#  'itarema',
#  'brae',
#  'riohacha',
#  'weyburn',
#  'axim',
#  'hamilton',
#  'vardo',
#  'punta arenas',
#  'moron',
#  'grand gaube',
#  'puerto el triunfo',
#  'talnakh',
#  'bengkulu',
#  'gamba',
#  'cape town',
#  'padang',
#  'puerto ayora',
#  'spearfish',
#  'longyearbyen',
#  'lavrentiya',
#  'arraial do cabo',
#  'faya',
#  'oneonta',
#  'clyde river',
#  'vaini',
#  'sitka',
#  'dikson',
#  'ahuimanu',
#  'hasaki',
#  'galgani',
#  'te anau',
#  'isiro',
#  'atuona',
#  'erdenet',
#  'nikolskoye',
#  'borovichi',
#  'antofagasta',
#  'batagay',
#  'kruisfontein',
#  'kavaratti',
#  'luderitz',
#  'upernavik',
#  'tazovskiy',
#  'bereda',
#  'hermanus',
#  'port lincoln',
#  'severo-kurilsk',
#  'katherine',
#  'olafsvik',
#  'doctor pedro p. pena',
#  'tasiilaq',
#  'campo de criptana',
#  'bayevo',
#  'deep river',
#  'cidreira',
#  'shunyi',
#  'new norfolk',
#  'kenai',
#  'meulaboh',
#  'solnechnyy',
#  'siguiri',
#  'saint-augustin',
#  'khatanga',
#  'coihaique',
#  'palabuhanratu',
#  'lima',
#  'humaita',
#  'luanda',
#  'yellowknife',
#  'maragogi',
#  'tuktoyaktuk',
#  'cockburn town',
#  'jalu',
#  'cayenne',
#  'bluff',
#  'avarua',
#  'ostrovnoy',
#  'krasnoselkup',
#  'mapimi',
#  'pinotepa nacional',
#  'samusu',
#  'borisoglebskiy',
#  'boca do acre',
#  'bambous virieux',
#  'swedru',
#  'barrow',
#  'sovetskiy',
#  'kaitangata',
#  'westport',
#  'armacao dos buzios',
#  'katsuura',
#  'sentyabrskiy',
#  'lebu',
#  'torbay',
#  'tabas',
#  'luau',
#  'santa cruz',
#  'poum',
#  'belushya guba',
#  'ribeira brava',
#  'illoqqortoormiut',
#  'pangnirtung',
#  'berlevag',
#  'port elizabeth',
#  'east london',
#  'toliary',
#  'chadan',
#  'darnah',
#  'kodiak',
#  'otane',
#  'grao mogol',
#  'brookhaven',
#  'zheshart',
#  'guerrero negro',
#  'alyangula',
#  'taltal',
#  'bossier city',
#  'airai',
#  'rawannawi',
#  'avera',
#  'leningradskiy',
#  'iglino',
#  'nioro',
#  'harper',
#  'ganta',
#  'marcona',
#  'rawson',
#  'wajima',
#  'catamarca',
#  'deer lake',
#  'roald',
#  'kavieng',
#  'porto walter',
#  'kuchaman',
#  'simao',
#  'mar del plata',
#  'acari',
#  'ust-kamchatsk',
#  'uchaly',
#  'codrington',
#  'hangu',
#  'camiri',
#  'butaritari',
#  'esperance',
#  'ampanihy',
#  'thompson',
#  'kapaa',
#  'visnes',
#  'isangel',
#  'qaanaaq',
#  'eldoret',
#  'solenzo',
#  'sao jose da coroa grande',
#  'ilinsko-podomskoye',
#  'barawe',
#  'tarpon springs',
#  'poptun',
#  'ribeira grande',
#  'trogir',
#  'kamenskoye',
#  'chicomuselo',
#  'nouadhibou',
#  'vaitupu',
#  'show low',
#  'naze',
#  'atar',
#  'maltahohe',
#  'dosso',
#  'saint george',
#  'ararat',
#  'kalininskaya',
#  'tavai',
#  'balud',
#  'victoria',
#  'saleaula',
#  'estevan',
#  'safford',
#  'huinan',
#  'shimoda',
#  'caravelas',
#  'steamboat springs',
#  'sakakah',
#  'outlook',
#  'baiyin',
#  'tumannyy',
#  'balikpapan',
#  'praia',
#  'port macquarie',
#  'hithadhoo',
#  'karibib',
#  'bathsheba',
#  'khandbari',
#  'tonota',
#  'gladstone',
#  'mount isa',
#  'bredasdorp',
#  'salekhard',
#  'strezhevoy',
#  'aykhal',
#  'samalaeulu',
#  'marienburg',
#  'kaisiadorys',
#  'marawi',
#  'korla',
#  'manokwari',
#  'kerman',
#  'rongcheng',
#  'yinchuan',
#  'acultzingo',
#  'anton lizardo',
#  'nome',
#  'lompoc',
#  'iqaluit',
#  'kulhudhuffushi',
#  'ifanadiana',
#  'uvinza',
#  'vaikam',
#  'margate',
#  'pauini',
#  'barra do garcas',
#  'chimbote',
#  'bilma',
#  'sola',
#  'port blair',
#  'sao joao da barra',
#  'jining',
#  'along',
#  'bemidji',
#  'laem sing',
#  'saskylakh',
#  'chokurdakh',
#  'olden',
#  'walvis bay',
#  'sorland',
#  'tuatapere',
#  'palmerston',
#  'kudahuvadhoo',
#  'san cristobal',
#  'sassandra',
#  'warragul',
#  'cururupu',
#  'ardakan',
#  'kundiawa',
#  'san martin',
#  'tidore',
#  'khuzhir',
#  'fortuna',
#  'pathein',
#  'tuy hoa',
#  'port shepstone',
#  'verkhnevilyuysk',
#  'san-pedro',
#  'ystad',
#  'vila franca do campo',
#  'grafton',
#  'maraa',
#  'nizhniy kuranakh',
#  'shubarshi',
#  'vagur',
#  'presidencia roque saenz pena',
#  'gubkinskiy',
#  'torrington',
#  'veere',
#  'adrar',
#  'houma',
#  'provideniya',
#  'ariquemes',
#  'staryy nadym',
#  'husavik',
#  'mizan teferi',
#  'ternate',
#  'aykino',
#  'weihe',
#  'tefe',
#  'gumdag',
#  'pontian kecil',
#  'bahia de caraquez',
#  'attawapiskat',
#  'biltine',
#  'the valley',
#  'puro',
#  'binzhou',
#  'lasa',
#  'kloulklubed',
#  'komsomolskiy',
#  'mattru',
#  'faanui',
#  'angoram',
#  'lake city',
#  'marsh harbour',
#  'jizan',
#  'sterling',
#  'hailar',
#  'port hedland',
#  'los llanos de aridane',
#  'aklavik',
#  'saint-pierre',
#  'sao goncalo do sapucai',
#  'kalianget',
#  'turiacu',
#  'nanortalik',
#  'sorong',
#  'fare',
#  'yerbogachen',
#  'tabiauea',
#  'sinnamary',
#  'mudgee',
#  'salalah',
#  'pemba',
#  'san jose',
#  'najran',
#  'oia',
#  'tsihombe',
#  'lar gerd',
#  'mitsamiouli',
#  'man',
#  'havlickuv brod',
#  'boca de parita',
#  'barentsburg',
#  'asau',
#  'dalinghe',
#  'abu samrah',
#  'guarapuava',
#  'san roque',
#  'rapid valley',
#  'xichang',
#  'zhigansk',
#  'berbera',
#  'requena',
#  'tahta',
#  'saint-francois',
#  'mitzic',
#  'onalaska',
#  'excelsior springs',
#  'jiroft',
#  'hay river',
#  'shitanjing',
#  'toronto',
#  'victor harbor',
#  'orichi',
#  'guarapari',
#  'matagami',
#  'nizhneyansk',
#  'bo',
#  'vallenar',
#  'vavuniya',
#  'vanimo',
#  'mehamn',
#  'sombrerete',
#  'yulara',
#  'mutsamudu',
#  'honiara',
#  'lorengau',
#  'haines junction',
#  'miraflores',
#  'tiksi',
#  'cam pha',
#  'norman wells',
#  'lazaro cardenas',
#  'puerto baquerizo moreno',
#  'taketa',
#  'louisbourg',
#  'banda aceh',
#  'gillette',
#  'khadki',
#  'anaconda',
#  'muros',
#  'neepawa',
#  'ustye',
#  'cherskiy',
#  'skibbereen',
#  'daru',
#  'ichinohe',
#  'hukuntsi',
#  'matcha',
#  'milingimbi',
#  'laguna',
#  'alice springs',
#  'tilichiki',
#  'talcahuano',
#  'tatawin',
#  'laiyang',
#  'olinda',
#  'kangaatsiaq',
#  'poso',
#  'kokoda',
#  'mareeba',
#  'kuytun',
#  'road town',
#  'sur',
#  'pontes e lacerda',
#  'denpasar',
#  'magdalena',
#  'prainha',
#  'dunedin',
#  'eldorado',
#  'tungor',
#  'ginda',
#  'kerteh',
#  'mayo',
#  'gat',
#  'tono',
#  'beihai',
#  'agadez',
#  'nemuro',
#  'praia da vitoria',
#  'yenotayevka',
#  'kudat',
#  'ouadda',
#  'sydney',
#  'barcelos',
#  'atambua',
#  'champerico',
#  'kikwit',
#  'shelburne',
#  'novorudnyy',
#  'chengmai',
#  'nyurba',
#  'urumqi',
#  'villarrica',
#  'venado tuerto',
#  'kysyl-syr',
#  'cabo san lucas',
#  'san quintin',
#  'florianopolis',
#  'sungaipenuh',
#  'iwanai',
#  'koulikoro',
#  'inhambane',
#  'pisco',
#  'okhotsk',
#  'kushikino',
#  'kapit',
#  'danielskuil',
#  'mys shmidta',
#  'mpika',
#  'ambilobe',
#  'caluquembe',
#  'pokrovsk',
#  'gazanjyk',
#  'verkhnetulomskiy',
#  'baijiantan',
#  'darhan',
#  'tombouctou',
#  'tromso',
#  'prince rupert',
#  'karauzyak',
#  'deputatskiy',
#  'kon tum',
#  'tura',
#  'palasa',
#  'huarmey',
#  'kosh-agach',
#  'oranjestad',
#  'tungkang',
#  'birjand',
#  'cap malheureux',
#  'hit',
#  'ahipara',
#  'bargal',
#  'paris',
#  'pontianak',
#  'buchanan',
#  'petauke',
#  'kilindoni',
#  'benghazi',
#  'vitoria',
#  'nawa',
#  'alofi',
#  'kisangani',
#  'constitucion',
#  'wattegama',
#  'redding',
#  'bandarbeyla',
#  'pyaozerskiy',
#  'platteville',
#  'benguela',
#  'dumraon',
#  'dzhusaly',
#  'guane',
#  'sao filipe',
#  'zhezkazgan',
#  'vostok',
#  'asosa',
#  'kailua',
#  'kiama',
#  'taoudenni',
#  'ballina',
#  'pringsewu',
#  'atasu',
#  'bonthe',
#  'tres arroyos',
#  'yumen',
#  'shaoguan',
#  'tuggurt',
#  'oistins',
#  'magadan',
#  'acapulco',
#  'waipawa',
#  'sisimiut',
#  'bati',
#  'calabozo',
#  'shizunai',
#  'xining',
#  'half moon bay',
#  'reconquista',
#  'leshukonskoye',
#  'dandong',
#  'richards bay',
#  'chapais',
#  'natal',
#  'tandil',
#  'ust-kuyga',
#  'kommunar',
#  'valpoi',
#  'ongandjera',
#  'dingle',
#  'matli',
#  'monchegorsk',
#  'lolua',
#  'chiredzi',
#  'kosa',
#  'igrim',
#  'evensk',
#  'tieli',
#  'troitskoye',
#  'touros',
#  'evanston',
#  'saint-paul',
#  'nishihara',
#  'pyshchug',
#  'ouegoa',
#  'la asuncion',
#  'havoysund',
#  'segou',
#  'trelew',
#  'beyneu',
#  'namibe',
#  'vestmanna',
#  'vila velha',
#  'bardiyah',
#  'el jicaro',
#  'aktau',
#  'kaeo',
#  'kahului',
#  'muyezerskiy',
#  'namatanai',
#  'senanga',
#  'eureka',
#  'kyren',
#  'bocas del toro',
#  'grand river south east',
#  'sao felix do xingu',
#  'kafue',
#  'durango',
#  'moissala',
#  'palmer',
#  'winnemucca',
#  'labuan',
#  'parthenay',
#  'vilhena',
#  'kovdor',
#  'khormuj',
#  'port augusta',
#  'flinders',
#  'odweyne',
#  'lithakia',
#  'sambhal',
#  'gurlan',
#  'zarubino',
#  'gambela',
#  'arlit',
#  'suntar',
#  'hinton',
#  'xuddur',
#  'gazli',
#  'broome',
#  'waingapu',
#  'calvinia',
#  'la cruz',
#  'elko',
#  'skalistyy',
#  'burica',
#  'tahe',
#  'havre-saint-pierre',
#  'stamsund',
#  'makinsk',
#  'narsaq',
#  'kholodnyy',
#  'mananjary',
#  'zalesovo',
#  'college',
#  'rungata',
#  'huadian',
#  'achisay',
#  'umm durman',
#  'mandalgovi',
#  'whitehorse',
#  'mount pleasant',
#  'uray',
#  'brentwood',
#  'terney',
#  'shaunavon',
#  'maloshuyka',
#  'verkhoyansk',
#  'san rafael',
#  'seoul',
#  'borama',
#  'mount darwin',
#  'benidorm',
#  'lamu',
#  'aban',
#  'hami',
#  'warqla',
#  'kirovskiy',
#  'constantine',
#  'tougue',
#  'kirakira',
#  'hofn',
#  'wenzhou',
#  'kalabo',
#  'beidao',
#  'simplicio mendes',
#  'keti bandar',
#  'tumut',
#  'san patricio',
#  'hirara',
#  'ilulissat',
#  'loviisa',
#  'santa cruz del sur',
#  'klaksvik',
#  'awbari',
#  'biscarrosse',
#  'plonsk',
#  'nanakuli',
#  'ayios matthaios',
#  'ciudad bolivar',
#  'boende',
#  'dukat',
#  'russell',
#  'los andes',
#  'kurchum',
#  'santa maria',
#  'iskateley',
#  'severo-yeniseyskiy',
#  'uvat',
#  'makung',
#  'port-gentil',
#  'murud',
#  'morgantown',
#  'klyuchi',
#  'afsin',
#  'soyo',
#  'santiago del estero',
#  'vila',
#  'campoverde',
#  'nueva loja',
#  'anchorage',
#  'balabac',
#  'oksfjord',
#  'capreol',
#  'chistogorskiy',
#  'coronel vivida',
#  'sitges',
#  'kayerkan',
#  'qinzhou',
#  'muriti',
#  'saint-louis',
#  'orange',
#  'buraydah',
#  'sackville',
#  'buariki',
#  'sabancuy',
#  'samana',
#  'halalo',
#  'vaitape',
#  'pagman',
#  'acatlan',
#  'rosarito',
#  'tigil',
#  'billund',
#  'pahalgam',
#  'inta',
#  'fort nelson',
#  'robertsport',
#  'coquimbo',
#  'ewa beach',
#  'menzelinsk',
#  'vestmannaeyjar',
#  'mamallapuram',
#  'patacamaya',
#  'podgorica',
#  'nuuk',
#  'paragould',
#  'gbadolite',
#  'dwarka',
#  'isla vista',
#  'haapiti',
#  'sioux lookout',
#  'kralendijk',
#  'khonuu',
#  'bandarban',
#  'tunduru',
#  'teguldet',
#  'coahuayana',
#  'kholtoson',
#  'jarabacoa',
#  'yar-sale',
#  'plettenberg bay',
#  'pietersburg',
#  'kerki',
#  'crab hill',
#  'mayumba',
#  'wellington',
#  'tankara',
#  'raudeberg',
#  'sao joao da ponte',
#  'mayskiy',
#  'rio de janeiro',
#  'beoumi',
#  'macia',
#  'nelson bay',
#  'shumikha',
#  'zhengjiatun',
#  'wagga wagga',
#  'ngukurr',
#  'prachuap khiri khan',
#  'sembakung',
#  'ostersund',
#  'thunder bay',
#  'morondava',
#  'jelling']

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                        "Country": city_country,
                        "Lat": city_lat,
                        "Lng": city_lng,
                        "Max Temp": city_max_temp,
                        "Humidity": city_humidity,
                        "Cloudiness": city_clouds,
                        "Wind Speed": city_wind,
                        "Current Description": city_desc})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | georgetown
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | bethel
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | kiruna
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | mackay
# Processing Record 8 of Set 1 | hilo
# Processing Record 9 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 1 | great falls
# Processing Record 11 of Set 1 | plouzane
# Processing Record 12 of Set 1 | shumerlya
# Processing Record 13 of Set 1 | souillac
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | phan rang
# City not found. Skipping...
# Processing Record 16 of Set 1 | minsk
# Processing Record 17 of Set 1 | carnarvon
# Processing Record 18 of Set 1 | port hardy
# Processing Record 19 of Set 1 | grand island
# Processing Record 20 of Set 1 | ponta do sol
# Processing Record 21 of Set 1 | castro
# Processing Record 22 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 1 | williston
# Processing Record 24 of Set 1 | hualmay
# Processing Record 25 of Set 1 | hobart
# Processing Record 26 of Set 1 | beringovskiy
# Processing Record 27 of Set 1 | pevek
# Processing Record 28 of Set 1 | sidi ali
# Processing Record 29 of Set 1 | honningsvag
# Processing Record 30 of Set 1 | saint-philippe
# Processing Record 31 of Set 1 | chuy
# Processing Record 32 of Set 1 | mahebourg
# Processing Record 33 of Set 1 | busselton
# Processing Record 34 of Set 1 | karaul
# City not found. Skipping...
# Processing Record 35 of Set 1 | lagoa
# Processing Record 36 of Set 1 | jamestown
# Processing Record 37 of Set 1 | ancud
# Processing Record 38 of Set 1 | fairbanks
# Processing Record 39 of Set 1 | port alfred
# Processing Record 40 of Set 1 | tabukiniberu
# City not found. Skipping...
# Processing Record 41 of Set 1 | itarema
# Processing Record 42 of Set 1 | brae
# Processing Record 43 of Set 1 | riohacha
# Processing Record 44 of Set 1 | weyburn
# Processing Record 45 of Set 1 | axim
# Processing Record 46 of Set 1 | hamilton
# Processing Record 47 of Set 1 | vardo
# Processing Record 48 of Set 1 | punta arenas
# Processing Record 49 of Set 1 | moron
# Processing Record 50 of Set 1 | grand gaube
# Processing Record 1 of Set 2 | puerto el triunfo
# Processing Record 2 of Set 2 | talnakh
# Processing Record 3 of Set 2 | bengkulu
# Processing Record 4 of Set 2 | gamba
# Processing Record 5 of Set 2 | cape town
# Processing Record 6 of Set 2 | padang
# Processing Record 7 of Set 2 | puerto ayora
# Processing Record 8 of Set 2 | spearfish
# Processing Record 9 of Set 2 | longyearbyen
# Processing Record 10 of Set 2 | lavrentiya
# Processing Record 11 of Set 2 | arraial do cabo
# Processing Record 12 of Set 2 | faya
# Processing Record 13 of Set 2 | oneonta
# Processing Record 14 of Set 2 | clyde river
# Processing Record 15 of Set 2 | vaini
# Processing Record 16 of Set 2 | sitka
# Processing Record 17 of Set 2 | dikson
# Processing Record 18 of Set 2 | ahuimanu
# Processing Record 19 of Set 2 | hasaki
# Processing Record 20 of Set 2 | galgani
# City not found. Skipping...
# Processing Record 21 of Set 2 | te anau
# Processing Record 22 of Set 2 | isiro
# Processing Record 23 of Set 2 | atuona
# Processing Record 24 of Set 2 | erdenet
# Processing Record 25 of Set 2 | nikolskoye
# Processing Record 26 of Set 2 | borovichi
# Processing Record 27 of Set 2 | antofagasta
# Processing Record 28 of Set 2 | batagay
# Processing Record 29 of Set 2 | kruisfontein
# Processing Record 30 of Set 2 | kavaratti
# Processing Record 31 of Set 2 | luderitz
# Processing Record 32 of Set 2 | upernavik
# Processing Record 33 of Set 2 | tazovskiy
# Processing Record 34 of Set 2 | bereda
# Processing Record 35 of Set 2 | hermanus
# Processing Record 36 of Set 2 | port lincoln
# Processing Record 37 of Set 2 | severo-kurilsk
# Processing Record 38 of Set 2 | katherine
# Processing Record 39 of Set 2 | olafsvik
# Processing Record 40 of Set 2 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 41 of Set 2 | tasiilaq
# Processing Record 42 of Set 2 | campo de criptana
# Processing Record 43 of Set 2 | bayevo
# Processing Record 44 of Set 2 | deep river
# Processing Record 45 of Set 2 | cidreira
# Processing Record 46 of Set 2 | shunyi
# Processing Record 47 of Set 2 | new norfolk
# Processing Record 48 of Set 2 | kenai
# Processing Record 49 of Set 2 | meulaboh
# Processing Record 50 of Set 2 | solnechnyy
# Processing Record 1 of Set 3 | siguiri
# Processing Record 2 of Set 3 | saint-augustin
# Processing Record 3 of Set 3 | khatanga
# Processing Record 4 of Set 3 | coihaique
# Processing Record 5 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 6 of Set 3 | lima
# Processing Record 7 of Set 3 | humaita
# Processing Record 8 of Set 3 | luanda
# Processing Record 9 of Set 3 | yellowknife
# Processing Record 10 of Set 3 | maragogi
# Processing Record 11 of Set 3 | tuktoyaktuk
# Processing Record 12 of Set 3 | cockburn town
# Processing Record 13 of Set 3 | jalu
# Processing Record 14 of Set 3 | cayenne
# Processing Record 15 of Set 3 | bluff
# Processing Record 16 of Set 3 | avarua
# Processing Record 17 of Set 3 | ostrovnoy
# Processing Record 18 of Set 3 | krasnoselkup
# Processing Record 19 of Set 3 | mapimi
# Processing Record 20 of Set 3 | pinotepa nacional
# Processing Record 21 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 3 | borisoglebskiy
# Processing Record 23 of Set 3 | boca do acre
# Processing Record 24 of Set 3 | bambous virieux
# Processing Record 25 of Set 3 | swedru
# Processing Record 26 of Set 3 | barrow
# Processing Record 27 of Set 3 | sovetskiy
# Processing Record 28 of Set 3 | kaitangata
# Processing Record 29 of Set 3 | westport
# Processing Record 30 of Set 3 | armacao dos buzios
# City not found. Skipping...
# Processing Record 31 of Set 3 | katsuura
# Processing Record 32 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 33 of Set 3 | lebu
# Processing Record 34 of Set 3 | torbay
# Processing Record 35 of Set 3 | tabas
# Processing Record 36 of Set 3 | luau
# Processing Record 37 of Set 3 | santa cruz
# Processing Record 38 of Set 3 | poum
# Processing Record 39 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 40 of Set 3 | ribeira brava
# Processing Record 41 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 42 of Set 3 | pangnirtung
# Processing Record 43 of Set 3 | berlevag
# Processing Record 44 of Set 3 | port elizabeth
# Processing Record 45 of Set 3 | east london
# Processing Record 46 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 47 of Set 3 | chadan
# Processing Record 48 of Set 3 | darnah
# Processing Record 49 of Set 3 | kodiak
# Processing Record 50 of Set 3 | otane
# Processing Record 1 of Set 4 | grao mogol
# Processing Record 2 of Set 4 | brookhaven
# Processing Record 3 of Set 4 | zheshart
# Processing Record 4 of Set 4 | guerrero negro
# Processing Record 5 of Set 4 | alyangula
# Processing Record 6 of Set 4 | taltal
# Processing Record 7 of Set 4 | bossier city
# Processing Record 8 of Set 4 | airai
# Processing Record 9 of Set 4 | rawannawi
# City not found. Skipping...
# Processing Record 10 of Set 4 | avera
# Processing Record 11 of Set 4 | leningradskiy
# Processing Record 12 of Set 4 | iglino
# Processing Record 13 of Set 4 | nioro
# Processing Record 14 of Set 4 | harper
# Processing Record 15 of Set 4 | ganta
# Processing Record 16 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 17 of Set 4 | rawson
# Processing Record 18 of Set 4 | wajima
# Processing Record 19 of Set 4 | catamarca
# Processing Record 20 of Set 4 | deer lake
# Processing Record 21 of Set 4 | roald
# Processing Record 22 of Set 4 | kavieng
# Processing Record 23 of Set 4 | porto walter
# Processing Record 24 of Set 4 | kuchaman
# Processing Record 25 of Set 4 | simao
# Processing Record 26 of Set 4 | mar del plata
# Processing Record 27 of Set 4 | acari
# Processing Record 28 of Set 4 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 29 of Set 4 | uchaly
# Processing Record 30 of Set 4 | codrington
# Processing Record 31 of Set 4 | hangu
# Processing Record 32 of Set 4 | camiri
# Processing Record 33 of Set 4 | butaritari
# Processing Record 34 of Set 4 | esperance
# Processing Record 35 of Set 4 | ampanihy
# Processing Record 36 of Set 4 | thompson
# Processing Record 37 of Set 4 | kapaa
# Processing Record 38 of Set 4 | visnes
# Processing Record 39 of Set 4 | isangel
# Processing Record 40 of Set 4 | qaanaaq
# Processing Record 41 of Set 4 | eldoret
# Processing Record 42 of Set 4 | solenzo
# Processing Record 43 of Set 4 | sao jose da coroa grande
# Processing Record 44 of Set 4 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 45 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 46 of Set 4 | tarpon springs
# Processing Record 47 of Set 4 | poptun
# Processing Record 48 of Set 4 | ribeira grande
# Processing Record 49 of Set 4 | trogir
# Processing Record 50 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 1 of Set 5 | chicomuselo
# Processing Record 2 of Set 5 | nouadhibou
# Processing Record 3 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 5 | show low
# Processing Record 5 of Set 5 | naze
# Processing Record 6 of Set 5 | atar
# Processing Record 7 of Set 5 | maltahohe
# Processing Record 8 of Set 5 | dosso
# Processing Record 9 of Set 5 | saint george
# Processing Record 10 of Set 5 | ararat
# Processing Record 11 of Set 5 | kalininskaya
# Processing Record 12 of Set 5 | tavai
# City not found. Skipping...
# Processing Record 13 of Set 5 | balud
# Processing Record 14 of Set 5 | victoria
# Processing Record 15 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 5 | estevan
# Processing Record 17 of Set 5 | safford
# Processing Record 18 of Set 5 | huinan
# Processing Record 19 of Set 5 | shimoda
# Processing Record 20 of Set 5 | caravelas
# Processing Record 21 of Set 5 | steamboat springs
# Processing Record 22 of Set 5 | sakakah
# Processing Record 23 of Set 5 | outlook
# Processing Record 24 of Set 5 | baiyin
# Processing Record 25 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 5 | balikpapan
# Processing Record 27 of Set 5 | praia
# Processing Record 28 of Set 5 | port macquarie
# Processing Record 29 of Set 5 | hithadhoo
# Processing Record 30 of Set 5 | karibib
# Processing Record 31 of Set 5 | bathsheba
# Processing Record 32 of Set 5 | khandbari
# Processing Record 33 of Set 5 | tonota
# Processing Record 34 of Set 5 | gladstone
# Processing Record 35 of Set 5 | mount isa
# Processing Record 36 of Set 5 | bredasdorp
# Processing Record 37 of Set 5 | salekhard
# Processing Record 38 of Set 5 | strezhevoy
# Processing Record 39 of Set 5 | aykhal
# Processing Record 40 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 41 of Set 5 | marienburg
# Processing Record 42 of Set 5 | kaisiadorys
# Processing Record 43 of Set 5 | marawi
# Processing Record 44 of Set 5 | korla
# Processing Record 45 of Set 5 | manokwari
# Processing Record 46 of Set 5 | kerman
# Processing Record 47 of Set 5 | rongcheng
# Processing Record 48 of Set 5 | yinchuan
# Processing Record 49 of Set 5 | acultzingo
# Processing Record 50 of Set 5 | anton lizardo
# Processing Record 1 of Set 6 | nome
# Processing Record 2 of Set 6 | lompoc
# Processing Record 3 of Set 6 | iqaluit
# Processing Record 4 of Set 6 | kulhudhuffushi
# Processing Record 5 of Set 6 | ifanadiana
# Processing Record 6 of Set 6 | uvinza
# Processing Record 7 of Set 6 | vaikam
# Processing Record 8 of Set 6 | margate
# Processing Record 9 of Set 6 | pauini
# Processing Record 10 of Set 6 | barra do garcas
# Processing Record 11 of Set 6 | chimbote
# Processing Record 12 of Set 6 | bilma
# Processing Record 13 of Set 6 | sola
# Processing Record 14 of Set 6 | port blair
# Processing Record 15 of Set 6 | sao joao da barra
# Processing Record 16 of Set 6 | jining
# Processing Record 17 of Set 6 | along
# Processing Record 18 of Set 6 | bemidji
# Processing Record 19 of Set 6 | laem sing
# Processing Record 20 of Set 6 | saskylakh
# Processing Record 21 of Set 6 | chokurdakh
# Processing Record 22 of Set 6 | olden
# Processing Record 23 of Set 6 | walvis bay
# Processing Record 24 of Set 6 | sorland
# Processing Record 25 of Set 6 | tuatapere
# Processing Record 26 of Set 6 | palmerston
# Processing Record 27 of Set 6 | kudahuvadhoo
# Processing Record 28 of Set 6 | san cristobal
# Processing Record 29 of Set 6 | sassandra
# Processing Record 30 of Set 6 | warragul
# Processing Record 31 of Set 6 | cururupu
# Processing Record 32 of Set 6 | ardakan
# Processing Record 33 of Set 6 | kundiawa
# Processing Record 34 of Set 6 | san martin
# Processing Record 35 of Set 6 | tidore
# City not found. Skipping...
# Processing Record 36 of Set 6 | khuzhir
# Processing Record 37 of Set 6 | fortuna
# Processing Record 38 of Set 6 | pathein
# Processing Record 39 of Set 6 | tuy hoa
# Processing Record 40 of Set 6 | port shepstone
# Processing Record 41 of Set 6 | verkhnevilyuysk
# Processing Record 42 of Set 6 | san-pedro
# Processing Record 43 of Set 6 | ystad
# Processing Record 44 of Set 6 | vila franca do campo
# Processing Record 45 of Set 6 | grafton
# Processing Record 46 of Set 6 | maraa
# Processing Record 47 of Set 6 | nizhniy kuranakh
# Processing Record 48 of Set 6 | shubarshi
# Processing Record 49 of Set 6 | vagur
# Processing Record 50 of Set 6 | presidencia roque saenz pena
# Processing Record 1 of Set 7 | gubkinskiy
# Processing Record 2 of Set 7 | torrington
# Processing Record 3 of Set 7 | veere
# Processing Record 4 of Set 7 | adrar
# Processing Record 5 of Set 7 | houma
# Processing Record 6 of Set 7 | provideniya
# Processing Record 7 of Set 7 | ariquemes
# Processing Record 8 of Set 7 | staryy nadym
# Processing Record 9 of Set 7 | husavik
# Processing Record 10 of Set 7 | mizan teferi
# Processing Record 11 of Set 7 | ternate
# Processing Record 12 of Set 7 | aykino
# Processing Record 13 of Set 7 | weihe
# Processing Record 14 of Set 7 | tefe
# Processing Record 15 of Set 7 | gumdag
# Processing Record 16 of Set 7 | pontian kecil
# Processing Record 17 of Set 7 | bahia de caraquez
# Processing Record 18 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 7 | biltine
# Processing Record 20 of Set 7 | the valley
# Processing Record 21 of Set 7 | puro
# Processing Record 22 of Set 7 | binzhou
# Processing Record 23 of Set 7 | lasa
# Processing Record 24 of Set 7 | kloulklubed
# Processing Record 25 of Set 7 | komsomolskiy
# Processing Record 26 of Set 7 | mattru
# Processing Record 27 of Set 7 | faanui
# Processing Record 28 of Set 7 | angoram
# Processing Record 29 of Set 7 | lake city
# Processing Record 30 of Set 7 | marsh harbour
# Processing Record 31 of Set 7 | jizan
# Processing Record 32 of Set 7 | sterling
# Processing Record 33 of Set 7 | hailar
# Processing Record 34 of Set 7 | port hedland
# Processing Record 35 of Set 7 | los llanos de aridane
# Processing Record 36 of Set 7 | aklavik
# Processing Record 37 of Set 7 | saint-pierre
# Processing Record 38 of Set 7 | sao goncalo do sapucai
# Processing Record 39 of Set 7 | kalianget
# Processing Record 40 of Set 7 | turiacu
# Processing Record 41 of Set 7 | nanortalik
# Processing Record 42 of Set 7 | sorong
# Processing Record 43 of Set 7 | fare
# Processing Record 44 of Set 7 | yerbogachen
# Processing Record 45 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 46 of Set 7 | sinnamary
# Processing Record 47 of Set 7 | mudgee
# Processing Record 48 of Set 7 | salalah
# Processing Record 49 of Set 7 | pemba
# Processing Record 50 of Set 7 | san jose
# Processing Record 1 of Set 8 | najran
# Processing Record 2 of Set 8 | oia
# Processing Record 3 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 8 | lar gerd
# City not found. Skipping...
# Processing Record 5 of Set 8 | mitsamiouli
# City not found. Skipping...
# Processing Record 6 of Set 8 | man
# Processing Record 7 of Set 8 | havlickuv brod
# Processing Record 8 of Set 8 | boca de parita
# Processing Record 9 of Set 8 | barentsburg
# City not found. Skipping...
# Processing Record 10 of Set 8 | asau
# Processing Record 11 of Set 8 | dalinghe
# City not found. Skipping...
# Processing Record 12 of Set 8 | abu samrah
# Processing Record 13 of Set 8 | guarapuava
# Processing Record 14 of Set 8 | san roque
# Processing Record 15 of Set 8 | rapid valley
# Processing Record 16 of Set 8 | xichang
# Processing Record 17 of Set 8 | zhigansk
# Processing Record 18 of Set 8 | berbera
# Processing Record 19 of Set 8 | requena
# Processing Record 20 of Set 8 | tahta
# Processing Record 21 of Set 8 | saint-francois
# Processing Record 22 of Set 8 | mitzic
# Processing Record 23 of Set 8 | onalaska
# Processing Record 24 of Set 8 | excelsior springs
# Processing Record 25 of Set 8 | jiroft
# City not found. Skipping...
# Processing Record 26 of Set 8 | hay river
# Processing Record 27 of Set 8 | shitanjing
# Processing Record 28 of Set 8 | toronto
# Processing Record 29 of Set 8 | victor harbor
# Processing Record 30 of Set 8 | orichi
# Processing Record 31 of Set 8 | guarapari
# Processing Record 32 of Set 8 | matagami
# Processing Record 33 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 8 | bo
# City not found. Skipping...
# Processing Record 35 of Set 8 | vallenar
# Processing Record 36 of Set 8 | vavuniya
# Processing Record 37 of Set 8 | vanimo
# Processing Record 38 of Set 8 | mehamn
# Processing Record 39 of Set 8 | sombrerete
# Processing Record 40 of Set 8 | yulara
# Processing Record 41 of Set 8 | mutsamudu
# City not found. Skipping...
# Processing Record 42 of Set 8 | honiara
# Processing Record 43 of Set 8 | lorengau
# Processing Record 44 of Set 8 | haines junction
# Processing Record 45 of Set 8 | miraflores
# Processing Record 46 of Set 8 | tiksi
# Processing Record 47 of Set 8 | cam pha
# City not found. Skipping...
# Processing Record 48 of Set 8 | norman wells
# Processing Record 49 of Set 8 | lazaro cardenas
# Processing Record 50 of Set 8 | puerto baquerizo moreno
# Processing Record 1 of Set 9 | taketa
# Processing Record 2 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 3 of Set 9 | banda aceh
# Processing Record 4 of Set 9 | gillette
# Processing Record 5 of Set 9 | khadki
# Processing Record 6 of Set 9 | anaconda
# Processing Record 7 of Set 9 | muros
# Processing Record 8 of Set 9 | neepawa
# Processing Record 9 of Set 9 | ustye
# Processing Record 10 of Set 9 | cherskiy
# Processing Record 11 of Set 9 | skibbereen
# Processing Record 12 of Set 9 | daru
# Processing Record 13 of Set 9 | ichinohe
# Processing Record 14 of Set 9 | hukuntsi
# Processing Record 15 of Set 9 | matcha
# Processing Record 16 of Set 9 | milingimbi
# City not found. Skipping...
# Processing Record 17 of Set 9 | laguna
# Processing Record 18 of Set 9 | alice springs
# Processing Record 19 of Set 9 | tilichiki
# Processing Record 20 of Set 9 | talcahuano
# Processing Record 21 of Set 9 | tatawin
# Processing Record 22 of Set 9 | laiyang
# Processing Record 23 of Set 9 | olinda
# Processing Record 24 of Set 9 | kangaatsiaq
# Processing Record 25 of Set 9 | poso
# Processing Record 26 of Set 9 | kokoda
# Processing Record 27 of Set 9 | mareeba
# Processing Record 28 of Set 9 | kuytun
# Processing Record 29 of Set 9 | road town
# Processing Record 30 of Set 9 | sur
# Processing Record 31 of Set 9 | pontes e lacerda
# Processing Record 32 of Set 9 | denpasar
# Processing Record 33 of Set 9 | magdalena
# Processing Record 34 of Set 9 | prainha
# Processing Record 35 of Set 9 | dunedin
# Processing Record 36 of Set 9 | eldorado
# Processing Record 37 of Set 9 | tungor
# Processing Record 38 of Set 9 | ginda
# Processing Record 39 of Set 9 | kerteh
# City not found. Skipping...
# Processing Record 40 of Set 9 | mayo
# Processing Record 41 of Set 9 | gat
# Processing Record 42 of Set 9 | tono
# Processing Record 43 of Set 9 | beihai
# Processing Record 44 of Set 9 | agadez
# Processing Record 45 of Set 9 | nemuro
# Processing Record 46 of Set 9 | praia da vitoria
# Processing Record 47 of Set 9 | yenotayevka
# Processing Record 48 of Set 9 | kudat
# Processing Record 49 of Set 9 | ouadda
# Processing Record 50 of Set 9 | sydney
# Processing Record 1 of Set 10 | barcelos
# Processing Record 2 of Set 10 | atambua
# Processing Record 3 of Set 10 | champerico
# Processing Record 4 of Set 10 | kikwit
# Processing Record 5 of Set 10 | shelburne
# Processing Record 6 of Set 10 | novorudnyy
# Processing Record 7 of Set 10 | chengmai
# City not found. Skipping...
# Processing Record 8 of Set 10 | nyurba
# Processing Record 9 of Set 10 | urumqi
# Processing Record 10 of Set 10 | villarrica
# Processing Record 11 of Set 10 | venado tuerto
# Processing Record 12 of Set 10 | kysyl-syr
# Processing Record 13 of Set 10 | cabo san lucas
# Processing Record 14 of Set 10 | san quintin
# Processing Record 15 of Set 10 | florianopolis
# Processing Record 16 of Set 10 | sungaipenuh
# Processing Record 17 of Set 10 | iwanai
# Processing Record 18 of Set 10 | koulikoro
# Processing Record 19 of Set 10 | inhambane
# Processing Record 20 of Set 10 | pisco
# Processing Record 21 of Set 10 | okhotsk
# Processing Record 22 of Set 10 | kushikino
# Processing Record 23 of Set 10 | kapit
# Processing Record 24 of Set 10 | danielskuil
# Processing Record 25 of Set 10 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 10 | mpika
# Processing Record 27 of Set 10 | ambilobe
# Processing Record 28 of Set 10 | caluquembe
# Processing Record 29 of Set 10 | pokrovsk
# Processing Record 30 of Set 10 | gazanjyk
# Processing Record 31 of Set 10 | verkhnetulomskiy
# Processing Record 32 of Set 10 | baijiantan
# Processing Record 33 of Set 10 | darhan
# Processing Record 34 of Set 10 | tombouctou
# Processing Record 35 of Set 10 | tromso
# Processing Record 36 of Set 10 | prince rupert
# Processing Record 37 of Set 10 | karauzyak
# City not found. Skipping...
# Processing Record 38 of Set 10 | deputatskiy
# Processing Record 39 of Set 10 | kon tum
# Processing Record 40 of Set 10 | tura
# Processing Record 41 of Set 10 | palasa
# Processing Record 42 of Set 10 | huarmey
# Processing Record 43 of Set 10 | kosh-agach
# Processing Record 44 of Set 10 | oranjestad
# Processing Record 45 of Set 10 | tungkang
# City not found. Skipping...
# Processing Record 46 of Set 10 | birjand
# Processing Record 47 of Set 10 | cap malheureux
# Processing Record 48 of Set 10 | hit
# Processing Record 49 of Set 10 | ahipara
# Processing Record 50 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 1 of Set 11 | paris
# Processing Record 2 of Set 11 | pontianak
# Processing Record 3 of Set 11 | buchanan
# Processing Record 4 of Set 11 | petauke
# Processing Record 5 of Set 11 | kilindoni
# Processing Record 6 of Set 11 | benghazi
# Processing Record 7 of Set 11 | vitoria
# Processing Record 8 of Set 11 | nawa
# Processing Record 9 of Set 11 | alofi
# Processing Record 10 of Set 11 | kisangani
# Processing Record 11 of Set 11 | constitucion
# Processing Record 12 of Set 11 | wattegama
# Processing Record 13 of Set 11 | redding
# Processing Record 14 of Set 11 | bandarbeyla
# Processing Record 15 of Set 11 | pyaozerskiy
# Processing Record 16 of Set 11 | platteville
# Processing Record 17 of Set 11 | benguela
# Processing Record 18 of Set 11 | dumraon
# Processing Record 19 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 20 of Set 11 | guane
# Processing Record 21 of Set 11 | sao filipe
# Processing Record 22 of Set 11 | zhezkazgan
# Processing Record 23 of Set 11 | vostok
# Processing Record 24 of Set 11 | asosa
# Processing Record 25 of Set 11 | kailua
# Processing Record 26 of Set 11 | kiama
# Processing Record 27 of Set 11 | taoudenni
# Processing Record 28 of Set 11 | ballina
# Processing Record 29 of Set 11 | pringsewu
# Processing Record 30 of Set 11 | atasu
# Processing Record 31 of Set 11 | bonthe
# Processing Record 32 of Set 11 | tres arroyos
# Processing Record 33 of Set 11 | yumen
# Processing Record 34 of Set 11 | shaoguan
# Processing Record 35 of Set 11 | tuggurt
# City not found. Skipping...
# Processing Record 36 of Set 11 | oistins
# Processing Record 37 of Set 11 | magadan
# Processing Record 38 of Set 11 | acapulco
# Processing Record 39 of Set 11 | waipawa
# Processing Record 40 of Set 11 | sisimiut
# Processing Record 41 of Set 11 | bati
# Processing Record 42 of Set 11 | calabozo
# Processing Record 43 of Set 11 | shizunai
# Processing Record 44 of Set 11 | xining
# Processing Record 45 of Set 11 | half moon bay
# Processing Record 46 of Set 11 | reconquista
# Processing Record 47 of Set 11 | leshukonskoye
# Processing Record 48 of Set 11 | dandong
# Processing Record 49 of Set 11 | richards bay
# Processing Record 50 of Set 11 | chapais
# Processing Record 1 of Set 12 | natal
# Processing Record 2 of Set 12 | tandil
# Processing Record 3 of Set 12 | ust-kuyga
# Processing Record 4 of Set 12 | kommunar
# Processing Record 5 of Set 12 | valpoi
# Processing Record 6 of Set 12 | ongandjera
# Processing Record 7 of Set 12 | dingle
# Processing Record 8 of Set 12 | matli
# Processing Record 9 of Set 12 | monchegorsk
# Processing Record 10 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 11 of Set 12 | chiredzi
# Processing Record 12 of Set 12 | kosa
# Processing Record 13 of Set 12 | igrim
# Processing Record 14 of Set 12 | evensk
# Processing Record 15 of Set 12 | tieli
# Processing Record 16 of Set 12 | troitskoye
# Processing Record 17 of Set 12 | touros
# Processing Record 18 of Set 12 | evanston
# Processing Record 19 of Set 12 | saint-paul
# Processing Record 20 of Set 12 | nishihara
# Processing Record 21 of Set 12 | pyshchug
# Processing Record 22 of Set 12 | ouegoa
# Processing Record 23 of Set 12 | la asuncion
# Processing Record 24 of Set 12 | havoysund
# Processing Record 25 of Set 12 | segou
# Processing Record 26 of Set 12 | trelew
# Processing Record 27 of Set 12 | beyneu
# Processing Record 28 of Set 12 | namibe
# Processing Record 29 of Set 12 | vestmanna
# Processing Record 30 of Set 12 | vila velha
# Processing Record 31 of Set 12 | bardiyah
# Processing Record 32 of Set 12 | el jicaro
# Processing Record 33 of Set 12 | aktau
# Processing Record 34 of Set 12 | kaeo
# Processing Record 35 of Set 12 | kahului
# Processing Record 36 of Set 12 | muyezerskiy
# Processing Record 37 of Set 12 | namatanai
# Processing Record 38 of Set 12 | senanga
# Processing Record 39 of Set 12 | eureka
# Processing Record 40 of Set 12 | kyren
# Processing Record 41 of Set 12 | bocas del toro
# Processing Record 42 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 12 | sao felix do xingu
# Processing Record 44 of Set 12 | kafue
# Processing Record 45 of Set 12 | durango
# Processing Record 46 of Set 12 | moissala
# Processing Record 47 of Set 12 | palmer
# Processing Record 48 of Set 12 | winnemucca
# Processing Record 49 of Set 12 | labuan
# Processing Record 50 of Set 12 | parthenay
# Processing Record 1 of Set 13 | vilhena
# Processing Record 2 of Set 13 | kovdor
# Processing Record 3 of Set 13 | khormuj
# City not found. Skipping...
# Processing Record 4 of Set 13 | port augusta
# Processing Record 5 of Set 13 | flinders
# Processing Record 6 of Set 13 | odweyne
# Processing Record 7 of Set 13 | lithakia
# Processing Record 8 of Set 13 | sambhal
# Processing Record 9 of Set 13 | gurlan
# Processing Record 10 of Set 13 | zarubino
# Processing Record 11 of Set 13 | gambela
# Processing Record 12 of Set 13 | arlit
# Processing Record 13 of Set 13 | suntar
# Processing Record 14 of Set 13 | hinton
# Processing Record 15 of Set 13 | xuddur
# Processing Record 16 of Set 13 | gazli
# Processing Record 17 of Set 13 | broome
# Processing Record 18 of Set 13 | waingapu
# Processing Record 19 of Set 13 | calvinia
# Processing Record 20 of Set 13 | la cruz
# Processing Record 21 of Set 13 | elko
# Processing Record 22 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 23 of Set 13 | burica
# City not found. Skipping...
# Processing Record 24 of Set 13 | tahe
# Processing Record 25 of Set 13 | havre-saint-pierre
# Processing Record 26 of Set 13 | stamsund
# City not found. Skipping...
# Processing Record 27 of Set 13 | makinsk
# Processing Record 28 of Set 13 | narsaq
# Processing Record 29 of Set 13 | kholodnyy
# Processing Record 30 of Set 13 | mananjary
# Processing Record 31 of Set 13 | zalesovo
# Processing Record 32 of Set 13 | college
# Processing Record 33 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 34 of Set 13 | huadian
# Processing Record 35 of Set 13 | achisay
# City not found. Skipping...
# Processing Record 36 of Set 13 | umm durman
# City not found. Skipping...
# Processing Record 37 of Set 13 | mandalgovi
# Processing Record 38 of Set 13 | whitehorse
# Processing Record 39 of Set 13 | mount pleasant
# Processing Record 40 of Set 13 | uray
# Processing Record 41 of Set 13 | brentwood
# Processing Record 42 of Set 13 | terney
# Processing Record 43 of Set 13 | shaunavon
# Processing Record 44 of Set 13 | maloshuyka
# City not found. Skipping...
# Processing Record 45 of Set 13 | verkhoyansk
# Processing Record 46 of Set 13 | san rafael
# Processing Record 47 of Set 13 | seoul
# Processing Record 48 of Set 13 | borama
# City not found. Skipping...
# Processing Record 49 of Set 13 | mount darwin
# Processing Record 50 of Set 13 | benidorm
# Processing Record 1 of Set 14 | lamu
# Processing Record 2 of Set 14 | aban
# Processing Record 3 of Set 14 | hami
# Processing Record 4 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 5 of Set 14 | kirovskiy
# Processing Record 6 of Set 14 | constantine
# Processing Record 7 of Set 14 | tougue
# Processing Record 8 of Set 14 | kirakira
# Processing Record 9 of Set 14 | hofn
# Processing Record 10 of Set 14 | wenzhou
# Processing Record 11 of Set 14 | kalabo
# Processing Record 12 of Set 14 | beidao
# Processing Record 13 of Set 14 | simplicio mendes
# Processing Record 14 of Set 14 | keti bandar
# Processing Record 15 of Set 14 | tumut
# Processing Record 16 of Set 14 | san patricio
# Processing Record 17 of Set 14 | hirara
# Processing Record 18 of Set 14 | ilulissat
# Processing Record 19 of Set 14 | loviisa
# Processing Record 20 of Set 14 | santa cruz del sur
# Processing Record 21 of Set 14 | klaksvik
# Processing Record 22 of Set 14 | awbari
# Processing Record 23 of Set 14 | biscarrosse
# Processing Record 24 of Set 14 | plonsk
# Processing Record 25 of Set 14 | nanakuli
# Processing Record 26 of Set 14 | ayios matthaios
# City not found. Skipping...
# Processing Record 27 of Set 14 | ciudad bolivar
# Processing Record 28 of Set 14 | boende
# Processing Record 29 of Set 14 | dukat
# Processing Record 30 of Set 14 | russell
# Processing Record 31 of Set 14 | los andes
# Processing Record 32 of Set 14 | kurchum
# Processing Record 33 of Set 14 | santa maria
# Processing Record 34 of Set 14 | iskateley
# Processing Record 35 of Set 14 | severo-yeniseyskiy
# Processing Record 36 of Set 14 | uvat
# Processing Record 37 of Set 14 | makung
# City not found. Skipping...
# Processing Record 38 of Set 14 | port-gentil
# Processing Record 39 of Set 14 | murud
# Processing Record 40 of Set 14 | morgantown
# Processing Record 41 of Set 14 | klyuchi
# Processing Record 42 of Set 14 | afsin
# Processing Record 43 of Set 14 | soyo
# Processing Record 44 of Set 14 | santiago del estero
# Processing Record 45 of Set 14 | vila
# Processing Record 46 of Set 14 | campoverde
# Processing Record 47 of Set 14 | nueva loja
# Processing Record 48 of Set 14 | anchorage
# Processing Record 49 of Set 14 | balabac
# Processing Record 50 of Set 14 | oksfjord
# Processing Record 1 of Set 15 | capreol
# Processing Record 2 of Set 15 | chistogorskiy
# Processing Record 3 of Set 15 | coronel vivida
# Processing Record 4 of Set 15 | sitges
# Processing Record 5 of Set 15 | kayerkan
# Processing Record 6 of Set 15 | qinzhou
# Processing Record 7 of Set 15 | muriti
# Processing Record 8 of Set 15 | saint-louis
# Processing Record 9 of Set 15 | orange
# Processing Record 10 of Set 15 | buraydah
# Processing Record 11 of Set 15 | sackville
# Processing Record 12 of Set 15 | buariki
# City not found. Skipping...
# Processing Record 13 of Set 15 | sabancuy
# Processing Record 14 of Set 15 | samana
# Processing Record 15 of Set 15 | halalo
# City not found. Skipping...
# Processing Record 16 of Set 15 | vaitape
# Processing Record 17 of Set 15 | pagman
# City not found. Skipping...
# Processing Record 18 of Set 15 | acatlan
# Processing Record 19 of Set 15 | rosarito
# Processing Record 20 of Set 15 | tigil
# Processing Record 21 of Set 15 | billund
# Processing Record 22 of Set 15 | pahalgam
# Processing Record 23 of Set 15 | inta
# Processing Record 24 of Set 15 | fort nelson
# Processing Record 25 of Set 15 | robertsport
# Processing Record 26 of Set 15 | coquimbo
# Processing Record 27 of Set 15 | ewa beach
# Processing Record 28 of Set 15 | menzelinsk
# Processing Record 29 of Set 15 | vestmannaeyjar
# Processing Record 30 of Set 15 | mamallapuram
# Processing Record 31 of Set 15 | patacamaya
# Processing Record 32 of Set 15 | podgorica
# Processing Record 33 of Set 15 | nuuk
# Processing Record 34 of Set 15 | paragould
# Processing Record 35 of Set 15 | gbadolite
# Processing Record 36 of Set 15 | dwarka
# Processing Record 37 of Set 15 | isla vista
# Processing Record 38 of Set 15 | haapiti
# Processing Record 39 of Set 15 | sioux lookout
# Processing Record 40 of Set 15 | kralendijk
# Processing Record 41 of Set 15 | khonuu
# City not found. Skipping...
# Processing Record 42 of Set 15 | bandarban
# Processing Record 43 of Set 15 | tunduru
# City not found. Skipping...
# Processing Record 44 of Set 15 | teguldet
# Processing Record 45 of Set 15 | coahuayana
# Processing Record 46 of Set 15 | kholtoson
# Processing Record 47 of Set 15 | jarabacoa
# Processing Record 48 of Set 15 | yar-sale
# Processing Record 49 of Set 15 | plettenberg bay
# Processing Record 50 of Set 15 | pietersburg
# Processing Record 1 of Set 16 | kerki
# City not found. Skipping...
# Processing Record 2 of Set 16 | crab hill
# City not found. Skipping...
# Processing Record 3 of Set 16 | mayumba
# Processing Record 4 of Set 16 | wellington
# Processing Record 5 of Set 16 | tankara
# Processing Record 6 of Set 16 | raudeberg
# Processing Record 7 of Set 16 | sao joao da ponte
# Processing Record 8 of Set 16 | mayskiy
# Processing Record 9 of Set 16 | rio de janeiro
# Processing Record 10 of Set 16 | beoumi
# Processing Record 11 of Set 16 | macia
# Processing Record 12 of Set 16 | nelson bay
# Processing Record 13 of Set 16 | shumikha
# Processing Record 14 of Set 16 | zhengjiatun
# Processing Record 15 of Set 16 | wagga wagga
# Processing Record 16 of Set 16 | ngukurr
# City not found. Skipping...
# Processing Record 17 of Set 16 | prachuap khiri khan
# Processing Record 18 of Set 16 | sembakung
# Processing Record 19 of Set 16 | ostersund
# Processing Record 20 of Set 16 | thunder bay
# Processing Record 21 of Set 16 | morondava
# Processing Record 22 of Set 16 | jelling
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.tail(100)
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 602  Simplicio Mendes      BR  -7.8539  -41.9103     98.60        29
# 603       Keti Bandar      PK  24.1447   67.4497     83.39        46
# 604             Tumut      AU -35.3000  148.2167     41.99        84
# 605      San Patricio      US  28.0170  -97.5169     80.49        86
# 606            Hirara      JP  24.8000  125.2833     76.82        69
# ..                ...     ...      ...       ...       ...       ...
# 697         Sembakung      ID   3.8167  117.2500     82.33        97
# 698         Ostersund      SE  63.1792   14.6357     46.85        81
# 699       Thunder Bay      CA  48.4001  -89.3168     35.56        87
# 700         Morondava      MG -20.2833   44.2833     81.14        65
# 701           Jelling      DK  55.7559    9.4258     51.12        92
#
#      Cloudiness  Wind Speed Current Description
# 602          36        6.71    scattered clouds
# 603           0        9.06           clear sky
# 604           0        3.60           clear sky
# 605          16        5.08          few clouds
# 606          26       23.29    scattered clouds
# ..          ...         ...                 ...
# 697          16        1.57          few clouds
# 698          54        5.75       broken clouds
# 699          82       10.45       broken clouds
# 700           0       19.86           clear sky
# 701          90        5.99                mist
#
# [100 rows x 9 columns]

# %%
city_data_df.to_csv('WeatherPy_Database.csv')
